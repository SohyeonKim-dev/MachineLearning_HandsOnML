# %% [markdown]
# <a href="https://colab.research.google.com/github/SohyeonKim-dev/MachineLearning_HandsOnML/blob/main/14_processing_sequences_using_rnns_and_cnns.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
assert sys.version_info >= (3, 5)

# Is this notebook running on Colab or Kaggle?
IS_COLAB = "google.colab" in sys.modules
IS_KAGGLE = "kaggle_secrets" in sys.modules

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# TensorFlow ≥2.0 is required
import tensorflow as tf
from tensorflow import keras
assert tf.__version__ >= "2.0"

if not tf.config.list_physical_devices('GPU'):
    print("No GPU was detected. LSTMs and CNNs can be very slow without a GPU.")
    if IS_COLAB:
        print("Go to Runtime > Change runtime and select a GPU hardware accelerator.")
    if IS_KAGGLE:
        print("Go to Settings > Accelerator and select GPU.")

# Common imports
import numpy as np
import os
from pathlib import Path

# to make this notebook's output stable across runs
np.random.seed(42)
tf.random.set_seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID = "rnn"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# # Basic RNNs
# ## Generate the Dataset

# %%
def generate_time_series(batch_size, n_steps):
    freq1, freq2, offsets1, offsets2 = np.random.rand(4, batch_size, 1)
    time = np.linspace(0, 1, n_steps)
    series = 0.5 * np.sin((time - offsets1) * (freq1 * 10 + 10))  #   wave 1
    series += 0.2 * np.sin((time - offsets2) * (freq2 * 20 + 20)) # + wave 2
    series += 0.1 * (np.random.rand(batch_size, n_steps) - 0.5)   # + noise
    return series[..., np.newaxis].astype(np.float32)

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 1)
X_train, y_train = series[:7000, :n_steps], series[:7000, -1]
X_valid, y_valid = series[7000:9000, :n_steps], series[7000:9000, -1]
X_test, y_test = series[9000:, :n_steps], series[9000:, -1]

# %%
X_train.shape, y_train.shape
# Out:
# ((7000, 50, 1), (7000, 1))

# %%
def plot_series(series, y=None, y_pred=None, x_label="$t$", y_label="$x(t)$", legend=True):
    plt.plot(series, ".-")
    if y is not None:
        plt.plot(n_steps, y, "bo", label="Target")
    if y_pred is not None:
        plt.plot(n_steps, y_pred, "rx", markersize=10, label="Prediction")
    plt.grid(True)
    if x_label:
        plt.xlabel(x_label, fontsize=16)
    if y_label:
        plt.ylabel(y_label, fontsize=16, rotation=0)
    plt.hlines(0, 0, 100, linewidth=1)
    plt.axis([0, n_steps + 1, -1, 1])
    if legend and (y or y_pred):
        plt.legend(fontsize=14, loc="upper left")

fig, axes = plt.subplots(nrows=1, ncols=3, sharey=True, figsize=(12, 4))
for col in range(3):
    plt.sca(axes[col])
    plot_series(X_valid[col, :, 0], y_valid[col, 0],
                y_label=("$x(t)$" if col==0 else None),
                legend=(col == 0))
save_fig("time_series_plot")
plt.show()
# Out:
# Saving figure time_series_plot

# %% [markdown]
# Computing Some Baselines

# %%
y_pred = X_valid[:, -1]
np.mean(keras.losses.mean_squared_error(y_valid, y_pred))
# Out:
# 0.020211367

# %%
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[50, 1]),
    keras.layers.Dense(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 5s 8ms/step - loss: 0.1001 - val_loss: 0.0545
# Epoch 2/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0379 - val_loss: 0.0266
# Epoch 3/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0202 - val_loss: 0.0157
# Epoch 4/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0131 - val_loss: 0.0116
# Epoch 5/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0103 - val_loss: 0.0098
# Epoch 6/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0089 - val_loss: 0.0087
# Epoch 7/20
# 219/219 [==============================] - 2s 7ms/step - loss: 0.0080 - val_loss: 0.0079
# Epoch 8/20
# 219/219 [==============================] - 1s 5ms/step - loss: 0.0073 - val_loss: 0.0071
# Epoch 9/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 10/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0061 - val_loss: 0.0062
# Epoch 11/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0057 - val_loss: 0.0057
# Epoch 12/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0054 - val_loss: 0.0055
# Epoch 13/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0052 - val_loss: 0.0052
# Epoch 14/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0049 - val_loss: 0.0049
# Epoch 15/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0048 - val_loss: 0.0048
# Epoch 16/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0046 - val_loss: 0.0048
# Epoch 17/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0045 - val_loss: 0.0045
# Epoch 18/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 19/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0043 - val_loss: 0.0043
# Epoch 20/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0042 - val_loss: 0.0042

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 63/63 [==============================] - 0s 2ms/step - loss: 0.0042
# 0.004168086219578981

# %%
def plot_learning_curves(loss, val_loss):
    plt.plot(np.arange(len(loss)) + 0.5, loss, "b.-", label="Training loss")
    plt.plot(np.arange(len(val_loss)) + 1, val_loss, "r.-", label="Validation loss")
    plt.gca().xaxis.set_major_locator(mpl.ticker.MaxNLocator(integer=True))
    plt.axis([1, 20, 0, 0.05])
    plt.legend(fontsize=14)
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.grid(True)

plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %% [markdown]
# # Using a Simple RNN

# %%
np.random.seed(42)
tf.random.set_seed(42)


model = keras.models.Sequential([
                                 keras.layers.SimpleRNN(1, input_shape=[None,1])                              
])

optimizer = keras.optimizers.Adam(learning_rate = 0.005)
model.compile(loss = "mse", optimizer = optimizer)
history = model.fit(X_train, y_train, epochs = 20, validation_data = (X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 13s 55ms/step - loss: 0.0967 - val_loss: 0.0489
# Epoch 2/20
# 219/219 [==============================] - 12s 53ms/step - loss: 0.0369 - val_loss: 0.0296
# Epoch 3/20
# 219/219 [==============================] - 11s 52ms/step - loss: 0.0253 - val_loss: 0.0218
# Epoch 4/20
# 219/219 [==============================] - 12s 53ms/step - loss: 0.0198 - val_loss: 0.0177
# Epoch 5/20
# 219/219 [==============================] - 12s 57ms/step - loss: 0.0166 - val_loss: 0.0151
# Epoch 6/20
# 219/219 [==============================] - 11s 51ms/step - loss: 0.0146 - val_loss: 0.0134
# Epoch 7/20
# 219/219 [==============================] - 11s 52ms/step - loss: 0.0132 - val_loss: 0.0123
# Epoch 8/20
# 219/219 [==============================] - 14s 64ms/step - loss: 0.0124 - val_loss: 0.0116
# Epoch 9/20
# 219/219 [==============================] - 16s 74ms/step - loss: 0.0118 - val_loss: 0.0112
# Epoch 10/20
# 219/219 [==============================] - 11s 52ms/step - loss: 0.0116 - val_loss: 0.0110
# Epoch 11/20
# 219/219 [==============================] - 12s 53ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 12/20
# 219/219 [==============================] - 11s 52ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 13/20
# 219/219 [==============================] - 11s 51ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 14/20
# 219/219 [==============================] - 11s 52ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 15/20
# 219/219 [==============================] - 12s 55ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 16/20
# 219/219 [==============================] - 12s 54ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 17/20
# 219/219 [==============================] - 13s 60ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 18/20
# 219/219 [==============================] - 12s 57ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 19/20
# 219/219 [==============================] - 14s 63ms/step - loss: 0.0114 - val_loss: 0.0109
# Epoch 20/20
# 219/219 [==============================] - 18s 82ms/step - loss: 0.0114 - val_loss: 0.0109

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 63/63 [==============================] - 1s 8ms/step - loss: 0.0109
# 0.010881561785936356

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %% [markdown]
# # Deep RNN : recurrent neural network

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.SimpleRNN(1)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 50s 219ms/step - loss: 0.0492 - val_loss: 0.0090
# Epoch 2/20
# 219/219 [==============================] - 42s 192ms/step - loss: 0.0070 - val_loss: 0.0065
# Epoch 3/20
# 219/219 [==============================] - 41s 187ms/step - loss: 0.0053 - val_loss: 0.0045
# Epoch 4/20
# 219/219 [==============================] - 47s 216ms/step - loss: 0.0045 - val_loss: 0.0040
# Epoch 5/20
# 219/219 [==============================] - 42s 193ms/step - loss: 0.0042 - val_loss: 0.0040
# Epoch 6/20
# 219/219 [==============================] - 39s 176ms/step - loss: 0.0038 - val_loss: 0.0036
# Epoch 7/20
# 219/219 [==============================] - 42s 193ms/step - loss: 0.0038 - val_loss: 0.0040
# Epoch 8/20
# 219/219 [==============================] - 38s 175ms/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 9/20
# 219/219 [==============================] - 39s 179ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 10/20
# 219/219 [==============================] - 39s 176ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 11/20
# 219/219 [==============================] - 40s 184ms/step - loss: 0.0034 - val_loss: 0.0030
# Epoch 12/20
# 219/219 [==============================] - 38s 175ms/step - loss: 0.0033 - val_loss: 0.0031
# Epoch 13/20
# 219/219 [==============================] - 72s 327ms/step - loss: 0.0034 - val_loss: 0.0031
# Epoch 14/20
# 219/219 [==============================] - 56s 254ms/step - loss: 0.0033 - val_loss: 0.0032
# Epoch 15/20
# 219/219 [==============================] - 66s 302ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 16/20
# 219/219 [==============================] - 56s 256ms/step - loss: 0.0035 - val_loss: 0.0030
# Epoch 17/20
# 219/219 [==============================] - 63s 290ms/step - loss: 0.0033 - val_loss: 0.0029
# Epoch 18/20
# 219/219 [==============================] - 39s 178ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 19/20
# 219/219 [==============================] - 39s 176ms/step - loss: 0.0032 - val_loss: 0.0029
# Epoch 20/20
# 219/219 [==============================] - 38s 174ms/step - loss: 0.0032 - val_loss: 0.0029

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 63/63 [==============================] - 1s 18ms/step - loss: 0.0029
# 0.002910560928285122

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
y_pred = model.predict(X_valid)
plot_series(X_valid[0, :, 0], y_valid[0, 0], y_pred[0, 0])
plt.show()

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20),
    keras.layers.Dense(1)
])

'''

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.SimpleRNN(1)
])

: 앞선 모델의 마지막 simple RNN을 Dense 층으로 교체!

'''

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))

# %%
model.evaluate(X_valid, y_valid)
# Out:
# 63/63 [==============================] - 1s 19ms/step - loss: 0.0029
# 0.002910560928285122

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %% [markdown]
# ## Forecasting Several Steps Ahead

# %%
np.random.seed(43) # not 42, as it would give the first series in the train set

series = generate_time_series(1, n_steps + 10)
X_new, Y_new = series[:, :n_steps], series[:, n_steps:]
X = X_new
for step_ahead in range(10):
    y_pred_one = model.predict(X[:, step_ahead:])[:, np.newaxis, :]
    X = np.concatenate([X, y_pred_one], axis=1)

Y_pred = X[:, n_steps:]

# %%
Y_pred.shape
# Out:
# (1, 10, 1)

# %%
def plot_multiple_forecasts(X, Y, Y_pred):
    n_steps = X.shape[1]
    ahead = Y.shape[1]
    plot_series(X[0, :, 0])
    plt.plot(np.arange(n_steps, n_steps + ahead), Y[0, :, 0], "bo-", label="Actual")
    plt.plot(np.arange(n_steps, n_steps + ahead), Y_pred[0, :, 0], "rx-", label="Forecast", markersize=10)
    plt.axis([0, n_steps + ahead, -1, 1])
    plt.legend(fontsize=14)

plot_multiple_forecasts(X_new, Y_new, Y_pred)
save_fig("forecast_ahead_plot")
plt.show()
# Out:
# Saving figure forecast_ahead_plot

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 10)
X_train, Y_train = series[:7000, :n_steps], series[:7000, -10:, 0]
X_valid, Y_valid = series[7000:9000, :n_steps], series[7000:9000, -10:, 0]
X_test, Y_test = series[9000:, :n_steps], series[9000:, -10:, 0]

# %%
X = X_valid
for step_ahead in range(10):
    y_pred_one = model.predict(X)[:, np.newaxis, :]
    X = np.concatenate([X, y_pred_one], axis=1)

Y_pred = X[:, n_steps:, 0]

# %%
Y_pred.shape
# Out:
# (2000, 10)

# %%
np.mean(keras.metrics.mean_squared_error(Y_valid, Y_pred))
# Out:
# 0.027945077

# %%
Y_naive_pred = np.tile(X_valid[:, -1], 10) # take the last time step value, and repeat it 10 times
np.mean(keras.metrics.mean_squared_error(Y_valid, Y_naive_pred))
# Out:
# 0.25697407

# %%
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[50, 1]),
    keras.layers.Dense(10)
])

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 1s 4ms/step - loss: 0.1343 - val_loss: 0.0606
# Epoch 2/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0496 - val_loss: 0.0425
# Epoch 3/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0385 - val_loss: 0.0353
# Epoch 4/20
# 219/219 [==============================] - 1s 4ms/step - loss: 0.0331 - val_loss: 0.0311
# Epoch 5/20
# 219/219 [==============================] - 1s 6ms/step - loss: 0.0298 - val_loss: 0.0283
# Epoch 6/20
# 219/219 [==============================] - 1s 4ms/step - loss: 0.0273 - val_loss: 0.0264
# Epoch 7/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0256 - val_loss: 0.0249
# Epoch 8/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0244 - val_loss: 0.0237
# Epoch 9/20
# 219/219 [==============================] - 1s 4ms/step - loss: 0.0234 - val_loss: 0.0229
# Epoch 10/20
# 219/219 [==============================] - 1s 4ms/step - loss: 0.0227 - val_loss: 0.0222
# Epoch 11/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0220 - val_loss: 0.0216
# Epoch 12/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0215 - val_loss: 0.0212
# Epoch 13/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0210 - val_loss: 0.0208
# Epoch 14/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0207 - val_loss: 0.0207
# Epoch 15/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0203 - val_loss: 0.0202
# Epoch 16/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0200 - val_loss: 0.0199
# Epoch 17/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0197 - val_loss: 0.0195
# Epoch 18/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0193 - val_loss: 0.0192
# Epoch 19/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0191 - val_loss: 0.0189
# Epoch 20/20
# 219/219 [==============================] - 1s 3ms/step - loss: 0.0188 - val_loss: 0.0187

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20),
    keras.layers.Dense(10)
])

# RNN 층이 들어가자, 속도 엄청 느려졌다.

model.compile(loss="mse", optimizer="adam")
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 26s 114ms/step - loss: 0.0669 - val_loss: 0.0317
# Epoch 2/20
# 219/219 [==============================] - 25s 114ms/step - loss: 0.0265 - val_loss: 0.0200
# Epoch 3/20
# 219/219 [==============================] - 34s 154ms/step - loss: 0.0183 - val_loss: 0.0160
# Epoch 4/20
# 219/219 [==============================] - 25s 116ms/step - loss: 0.0155 - val_loss: 0.0144
# Epoch 5/20
# 219/219 [==============================] - 25s 115ms/step - loss: 0.0139 - val_loss: 0.0118
# Epoch 6/20
# 219/219 [==============================] - 25s 114ms/step - loss: 0.0128 - val_loss: 0.0112
# Epoch 7/20
# 219/219 [==============================] - 24s 111ms/step - loss: 0.0122 - val_loss: 0.0110
# Epoch 8/20
# 219/219 [==============================] - 25s 115ms/step - loss: 0.0115 - val_loss: 0.0103
# Epoch 9/20
# 219/219 [==============================] - 24s 111ms/step - loss: 0.0111 - val_loss: 0.0112
# Epoch 10/20
# 219/219 [==============================] - 25s 112ms/step - loss: 0.0110 - val_loss: 0.0100
# Epoch 11/20
# 219/219 [==============================] - 24s 112ms/step - loss: 0.0108 - val_loss: 0.0103
# Epoch 12/20
# 219/219 [==============================] - 26s 117ms/step - loss: 0.0102 - val_loss: 0.0096
# Epoch 13/20
# 219/219 [==============================] - 24s 110ms/step - loss: 0.0104 - val_loss: 0.0100
# Epoch 14/20
# 219/219 [==============================] - 24s 111ms/step - loss: 0.0098 - val_loss: 0.0103
# Epoch 15/20
# 219/219 [==============================] - 25s 112ms/step - loss: 0.0095 - val_loss: 0.0107
# Epoch 16/20
# 219/219 [==============================] - 24s 111ms/step - loss: 0.0092 - val_loss: 0.0089
# Epoch 17/20
# 219/219 [==============================] - 24s 111ms/step - loss: 0.0094 - val_loss: 0.0111
# Epoch 18/20
# 219/219 [==============================] - 25s 113ms/step - loss: 0.0095 - val_loss: 0.0094
# Epoch 19/20
# 219/219 [==============================] - 25s 115ms/step - loss: 0.0093 - val_loss: 0.0083
# Epoch 20/20
# 219/219 [==============================] - 25s 113ms/step - loss: 0.0094 - val_loss: 0.0085

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, -10:, :]
Y_pred = model.predict(X_new)[..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %%
np.random.seed(42)

n_steps = 50
series = generate_time_series(10000, n_steps + 10)
X_train = series[:7000, :n_steps]
X_valid = series[7000:9000, :n_steps]
X_test = series[9000:, :n_steps]
Y = np.empty((10000, n_steps, 10))
for step_ahead in range(1, 10 + 1):
    Y[..., step_ahead - 1] = series[..., step_ahead:step_ahead + n_steps, 0]
Y_train = Y[:7000]
Y_valid = Y[7000:9000]
Y_test = Y[9000:]

# %%
X_train.shape, Y_train.shape
# Out:
# ((7000, 50, 1), (7000, 50, 10))

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

def last_time_step_mse(Y_true, Y_pred):
    return keras.metrics.mean_squared_error(Y_true[:, -1], Y_pred[:, -1])

model.compile(loss="mse", optimizer=keras.optimizers.Adam(learning_rate=0.01), metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 26s 113ms/step - loss: 0.0508 - last_time_step_mse: 0.0400 - val_loss: 0.0429 - val_last_time_step_mse: 0.0324
# Epoch 2/20
# 219/219 [==============================] - 25s 114ms/step - loss: 0.0395 - last_time_step_mse: 0.0283 - val_loss: 0.0352 - val_last_time_step_mse: 0.0244
# Epoch 3/20
# 219/219 [==============================] - 24s 111ms/step - loss: 0.0327 - last_time_step_mse: 0.0215 - val_loss: 0.0314 - val_last_time_step_mse: 0.0208
# Epoch 4/20
# 219/219 [==============================] - 24s 111ms/step - loss: 0.0297 - last_time_step_mse: 0.0188 - val_loss: 0.0277 - val_last_time_step_mse: 0.0156
# Epoch 5/20
# 219/219 [==============================] - 24s 110ms/step - loss: 0.0274 - last_time_step_mse: 0.0155 - val_loss: 0.0254 - val_last_time_step_mse: 0.0132
# Epoch 6/20
# 219/219 [==============================] - 24s 110ms/step - loss: 0.0248 - last_time_step_mse: 0.0121 - val_loss: 0.0244 - val_last_time_step_mse: 0.0113
# Epoch 7/20
# 219/219 [==============================] - 25s 115ms/step - loss: 0.0235 - last_time_step_mse: 0.0109 - val_loss: 0.0224 - val_last_time_step_mse: 0.0095
# Epoch 8/20
# 219/219 [==============================] - 25s 115ms/step - loss: 0.0217 - last_time_step_mse: 0.0087 - val_loss: 0.0217 - val_last_time_step_mse: 0.0093
# Epoch 9/20
# 219/219 [==============================] - 25s 114ms/step - loss: 0.0214 - last_time_step_mse: 0.0086 - val_loss: 0.0206 - val_last_time_step_mse: 0.0079
# Epoch 10/20
# 219/219 [==============================] - 25s 113ms/step - loss: 0.0213 - last_time_step_mse: 0.0089 - val_loss: 0.0212 - val_last_time_step_mse: 0.0090
# Epoch 11/20
# 219/219 [==============================] - 25s 112ms/step - loss: 0.0204 - last_time_step_mse: 0.0080 - val_loss: 0.0201 - val_last_time_step_mse: 0.0076
# Epoch 12/20
# 219/219 [==============================] - 25s 114ms/step - loss: 0.0203 - last_time_step_mse: 0.0082 - val_loss: 0.0202 - val_last_time_step_mse: 0.0085
# Epoch 13/20
# 219/219 [==============================] - 25s 112ms/step - loss: 0.0197 - last_time_step_mse: 0.0074 - val_loss: 0.0207 - val_last_time_step_mse: 0.0081
# Epoch 14/20
# 219/219 [==============================] - 25s 114ms/step - loss: 0.0192 - last_time_step_mse: 0.0071 - val_loss: 0.0193 - val_last_time_step_mse: 0.0072
# Epoch 15/20
# 219/219 [==============================] - 25s 113ms/step - loss: 0.0191 - last_time_step_mse: 0.0071 - val_loss: 0.0184 - val_last_time_step_mse: 0.0070
# Epoch 16/20
# 219/219 [==============================] - 25s 114ms/step - loss: 0.0189 - last_time_step_mse: 0.0069 - val_loss: 0.0194 - val_last_time_step_mse: 0.0087
# Epoch 17/20
# 219/219 [==============================] - 25s 114ms/step - loss: 0.0188 - last_time_step_mse: 0.0069 - val_loss: 0.0184 - val_last_time_step_mse: 0.0075
# Epoch 18/20
# 219/219 [==============================] - 25s 116ms/step - loss: 0.0186 - last_time_step_mse: 0.0069 - val_loss: 0.0179 - val_last_time_step_mse: 0.0065
# Epoch 19/20
# 219/219 [==============================] - 25s 114ms/step - loss: 0.0185 - last_time_step_mse: 0.0069 - val_loss: 0.0174 - val_last_time_step_mse: 0.0059
# Epoch 20/20
# 219/219 [==============================] - 25s 116ms/step - loss: 0.0185 - last_time_step_mse: 0.0070 - val_loss: 0.0193 - val_last_time_step_mse: 0.0078

# %%
np.random.seed(42)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, 50:, :]
Y_pred = model.predict(X_new)[:, -1][..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %% [markdown]
# # Deep RNN with Batch Norm

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.SimpleRNN(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.BatchNormalization(),
    keras.layers.SimpleRNN(20, return_sequences=True),
    keras.layers.BatchNormalization(),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 28s 119ms/step - loss: 0.1929 - last_time_step_mse: 0.1902 - val_loss: 0.0877 - val_last_time_step_mse: 0.0832
# Epoch 2/20
# 219/219 [==============================] - 25s 115ms/step - loss: 0.0537 - last_time_step_mse: 0.0449 - val_loss: 0.0549 - val_last_time_step_mse: 0.0462
# Epoch 3/20
# 219/219 [==============================] - 25s 116ms/step - loss: 0.0471 - last_time_step_mse: 0.0375 - val_loss: 0.0451 - val_last_time_step_mse: 0.0358
# Epoch 4/20
# 219/219 [==============================] - 25s 114ms/step - loss: 0.0437 - last_time_step_mse: 0.0337 - val_loss: 0.0418 - val_last_time_step_mse: 0.0314
# Epoch 5/20
# 219/219 [==============================] - 26s 117ms/step - loss: 0.0409 - last_time_step_mse: 0.0306 - val_loss: 0.0391 - val_last_time_step_mse: 0.0287
# Epoch 6/20
# 219/219 [==============================] - 25s 116ms/step - loss: 0.0385 - last_time_step_mse: 0.0275 - val_loss: 0.0379 - val_last_time_step_mse: 0.0273
# Epoch 7/20
# 219/219 [==============================] - 25s 115ms/step - loss: 0.0366 - last_time_step_mse: 0.0254 - val_loss: 0.0367 - val_last_time_step_mse: 0.0248
# Epoch 8/20
# 219/219 [==============================] - 25s 115ms/step - loss: 0.0349 - last_time_step_mse: 0.0235 - val_loss: 0.0363 - val_last_time_step_mse: 0.0249
# Epoch 9/20
# 219/219 [==============================] - 25s 114ms/step - loss: 0.0338 - last_time_step_mse: 0.0221 - val_loss: 0.0332 - val_last_time_step_mse: 0.0208
# Epoch 10/20
# 219/219 [==============================] - 25s 115ms/step - loss: 0.0329 - last_time_step_mse: 0.0214 - val_loss: 0.0335 - val_last_time_step_mse: 0.0214
# Epoch 11/20
# 219/219 [==============================] - 25s 114ms/step - loss: 0.0322 - last_time_step_mse: 0.0206 - val_loss: 0.0323 - val_last_time_step_mse: 0.0203
# Epoch 12/20
# 219/219 [==============================] - 25s 114ms/step - loss: 0.0316 - last_time_step_mse: 0.0198 - val_loss: 0.0333 - val_last_time_step_mse: 0.0210
# Epoch 13/20
# 219/219 [==============================] - 25s 113ms/step - loss: 0.0310 - last_time_step_mse: 0.0191 - val_loss: 0.0310 - val_last_time_step_mse: 0.0187
# Epoch 14/20
# 219/219 [==============================] - 24s 112ms/step - loss: 0.0305 - last_time_step_mse: 0.0186 - val_loss: 0.0310 - val_last_time_step_mse: 0.0189
# Epoch 15/20
# 219/219 [==============================] - 25s 114ms/step - loss: 0.0302 - last_time_step_mse: 0.0182 - val_loss: 0.0298 - val_last_time_step_mse: 0.0178
# Epoch 16/20
# 219/219 [==============================] - 25s 115ms/step - loss: 0.0296 - last_time_step_mse: 0.0176 - val_loss: 0.0293 - val_last_time_step_mse: 0.0174
# Epoch 17/20
# 219/219 [==============================] - 25s 114ms/step - loss: 0.0293 - last_time_step_mse: 0.0172 - val_loss: 0.0315 - val_last_time_step_mse: 0.0200
# Epoch 18/20
# 219/219 [==============================] - 25s 115ms/step - loss: 0.0289 - last_time_step_mse: 0.0168 - val_loss: 0.0295 - val_last_time_step_mse: 0.0174
# Epoch 19/20
# 219/219 [==============================] - 25s 113ms/step - loss: 0.0286 - last_time_step_mse: 0.0168 - val_loss: 0.0290 - val_last_time_step_mse: 0.0163
# Epoch 20/20
# 219/219 [==============================] - 25s 114ms/step - loss: 0.0281 - last_time_step_mse: 0.0161 - val_loss: 0.0288 - val_last_time_step_mse: 0.0164

# %% [markdown]
# # Deep RNNs with Layer Norm

# %%
from tensorflow.keras.layers import LayerNormalization




class LNSimpleRNNCell(keras.layers.Layer):
    def __init__(self, units, activation="tanh", **kwargs):
        super().__init__(**kwargs)
        self.state_size = units
        self.output_size = units
        self.simple_rnn_cell = keras.layers.SimpleRNNCell(units,
                                                          activation=None)
        self.layer_norm = LayerNormalization()
        self.activation = keras.activations.get(activation)
    def get_initial_state(self, inputs=None, batch_size=None, dtype=None):
        if inputs is not None:
            batch_size = tf.shape(inputs)[0]
            dtype = inputs.dtype
        return [tf.zeros([batch_size, self.state_size], dtype=dtype)]
    def call(self, inputs, states):
        outputs, new_states = self.simple_rnn_cell(inputs, states)
        norm_outputs = self.activation(self.layer_norm(outputs))
        return norm_outputs, [norm_outputs]




np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.RNN(LNSimpleRNNCell(20), return_sequences=True,
                     input_shape=[None, 1]),
    keras.layers.RNN(LNSimpleRNNCell(20), return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 58s 248ms/step - loss: 0.1668 - last_time_step_mse: 0.1624 - val_loss: 0.0738 - val_last_time_step_mse: 0.0686
# Epoch 2/20
# 219/219 [==============================] - 56s 256ms/step - loss: 0.0639 - last_time_step_mse: 0.0567 - val_loss: 0.0569 - val_last_time_step_mse: 0.0498
# Epoch 3/20
# 219/219 [==============================] - 53s 244ms/step - loss: 0.0538 - last_time_step_mse: 0.0462 - val_loss: 0.0504 - val_last_time_step_mse: 0.0428
# Epoch 4/20
# 219/219 [==============================] - 54s 247ms/step - loss: 0.0472 - last_time_step_mse: 0.0386 - val_loss: 0.0444 - val_last_time_step_mse: 0.0358
# Epoch 5/20
# 219/219 [==============================] - 53s 240ms/step - loss: 0.0416 - last_time_step_mse: 0.0316 - val_loss: 0.0390 - val_last_time_step_mse: 0.0284
# Epoch 6/20
# 219/219 [==============================] - 55s 250ms/step - loss: 0.0384 - last_time_step_mse: 0.0274 - val_loss: 0.0367 - val_last_time_step_mse: 0.0256
# Epoch 7/20
# 219/219 [==============================] - 56s 254ms/step - loss: 0.0364 - last_time_step_mse: 0.0254 - val_loss: 0.0349 - val_last_time_step_mse: 0.0239
# Epoch 8/20
# 219/219 [==============================] - 54s 247ms/step - loss: 0.0346 - last_time_step_mse: 0.0233 - val_loss: 0.0341 - val_last_time_step_mse: 0.0229
# Epoch 9/20
# 219/219 [==============================] - 55s 250ms/step - loss: 0.0335 - last_time_step_mse: 0.0221 - val_loss: 0.0334 - val_last_time_step_mse: 0.0227
# Epoch 10/20
# 219/219 [==============================] - 54s 247ms/step - loss: 0.0323 - last_time_step_mse: 0.0207 - val_loss: 0.0313 - val_last_time_step_mse: 0.0192
# Epoch 11/20
# 219/219 [==============================] - 54s 247ms/step - loss: 0.0314 - last_time_step_mse: 0.0194 - val_loss: 0.0300 - val_last_time_step_mse: 0.0180
# Epoch 12/20
# 219/219 [==============================] - 55s 251ms/step - loss: 0.0311 - last_time_step_mse: 0.0192 - val_loss: 0.0301 - val_last_time_step_mse: 0.0184
# Epoch 13/20
# 219/219 [==============================] - 55s 250ms/step - loss: 0.0299 - last_time_step_mse: 0.0178 - val_loss: 0.0289 - val_last_time_step_mse: 0.0168
# Epoch 14/20
# 219/219 [==============================] - 55s 250ms/step - loss: 0.0295 - last_time_step_mse: 0.0173 - val_loss: 0.0288 - val_last_time_step_mse: 0.0167
# Epoch 15/20
# 219/219 [==============================] - 54s 247ms/step - loss: 0.0291 - last_time_step_mse: 0.0170 - val_loss: 0.0289 - val_last_time_step_mse: 0.0167
# Epoch 16/20
# 219/219 [==============================] - 54s 246ms/step - loss: 0.0288 - last_time_step_mse: 0.0168 - val_loss: 0.0280 - val_last_time_step_mse: 0.0160
# Epoch 17/20
# 219/219 [==============================] - 54s 247ms/step - loss: 0.0285 - last_time_step_mse: 0.0164 - val_loss: 0.0284 - val_last_time_step_mse: 0.0164
# Epoch 18/20
# 219/219 [==============================] - 54s 247ms/step - loss: 0.0280 - last_time_step_mse: 0.0158 - val_loss: 0.0275 - val_last_time_step_mse: 0.0154
# Epoch 19/20
# 219/219 [==============================] - 54s 248ms/step - loss: 0.0280 - last_time_step_mse: 0.0159 - val_loss: 0.0278 - val_last_time_step_mse: 0.0150
# Epoch 20/20
# 219/219 [==============================] - 55s 251ms/step - loss: 0.0276 - last_time_step_mse: 0.0154 - val_loss: 0.0276 - val_last_time_step_mse: 0.0156

# %% [markdown]
# # Creating a Custom RNN Class

# %%
class MyRNN(keras.layers.Layer):
    def __init__(self, cell, return_sequences=False, **kwargs):
        super().__init__(**kwargs)
        self.cell = cell
        self.return_sequences = return_sequences
        self.get_initial_state = getattr(
            self.cell, "get_initial_state", self.fallback_initial_state)
    def fallback_initial_state(self, inputs):
        batch_size = tf.shape(inputs)[0]
        return [tf.zeros([batch_size, self.cell.state_size], dtype=inputs.dtype)]
    @tf.function
    def call(self, inputs):
        states = self.get_initial_state(inputs)
        shape = tf.shape(inputs)
        batch_size = shape[0]
        n_steps = shape[1]
        sequences = tf.TensorArray(
            inputs.dtype, size=(n_steps if self.return_sequences else 0))
        outputs = tf.zeros(shape=[batch_size, self.cell.output_size], dtype=inputs.dtype)
        for step in tf.range(n_steps):
            outputs, states = self.cell(inputs[:, step], states)
            if self.return_sequences:
                sequences = sequences.write(step, outputs)
        if self.return_sequences:
            return tf.transpose(sequences.stack(), [1, 0, 2])
        else:
            return outputs

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    MyRNN(LNSimpleRNNCell(20), return_sequences=True,
          input_shape=[None, 1]),
    MyRNN(LNSimpleRNNCell(20), return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=20,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 59s 258ms/step - loss: 0.1668 - last_time_step_mse: 0.1624 - val_loss: 0.0738 - val_last_time_step_mse: 0.0686
# Epoch 2/20
# 219/219 [==============================] - 60s 273ms/step - loss: 0.0639 - last_time_step_mse: 0.0567 - val_loss: 0.0569 - val_last_time_step_mse: 0.0498
# Epoch 3/20
# 219/219 [==============================] - 68s 310ms/step - loss: 0.0538 - last_time_step_mse: 0.0462 - val_loss: 0.0504 - val_last_time_step_mse: 0.0428
# Epoch 4/20
# 219/219 [==============================] - 57s 262ms/step - loss: 0.0472 - last_time_step_mse: 0.0386 - val_loss: 0.0444 - val_last_time_step_mse: 0.0358
# Epoch 5/20
# 219/219 [==============================] - 56s 258ms/step - loss: 0.0416 - last_time_step_mse: 0.0316 - val_loss: 0.0390 - val_last_time_step_mse: 0.0284
# Epoch 6/20
# 219/219 [==============================] - 57s 262ms/step - loss: 0.0384 - last_time_step_mse: 0.0274 - val_loss: 0.0367 - val_last_time_step_mse: 0.0256
# Epoch 7/20
# 219/219 [==============================] - 57s 263ms/step - loss: 0.0364 - last_time_step_mse: 0.0254 - val_loss: 0.0349 - val_last_time_step_mse: 0.0239
# Epoch 8/20
# 219/219 [==============================] - 56s 257ms/step - loss: 0.0346 - last_time_step_mse: 0.0233 - val_loss: 0.0341 - val_last_time_step_mse: 0.0229
# Epoch 9/20
# 219/219 [==============================] - 56s 256ms/step - loss: 0.0335 - last_time_step_mse: 0.0221 - val_loss: 0.0334 - val_last_time_step_mse: 0.0227
# Epoch 10/20
# 219/219 [==============================] - 56s 255ms/step - loss: 0.0323 - last_time_step_mse: 0.0207 - val_loss: 0.0313 - val_last_time_step_mse: 0.0192
# Epoch 11/20
# 219/219 [==============================] - 56s 257ms/step - loss: 0.0314 - last_time_step_mse: 0.0194 - val_loss: 0.0300 - val_last_time_step_mse: 0.0180
# Epoch 12/20
# 219/219 [==============================] - 56s 258ms/step - loss: 0.0311 - last_time_step_mse: 0.0192 - val_loss: 0.0301 - val_last_time_step_mse: 0.0184
# Epoch 13/20
# 219/219 [==============================] - 56s 255ms/step - loss: 0.0299 - last_time_step_mse: 0.0178 - val_loss: 0.0289 - val_last_time_step_mse: 0.0168
# Epoch 14/20
# 219/219 [==============================] - 56s 255ms/step - loss: 0.0295 - last_time_step_mse: 0.0173 - val_loss: 0.0288 - val_last_time_step_mse: 0.0167
# Epoch 15/20
# 219/219 [==============================] - 57s 259ms/step - loss: 0.0291 - last_time_step_mse: 0.0170 - val_loss: 0.0289 - val_last_time_step_mse: 0.0167
# Epoch 16/20
# 219/219 [==============================] - 56s 258ms/step - loss: 0.0288 - last_time_step_mse: 0.0168 - val_loss: 0.0280 - val_last_time_step_mse: 0.0160
# Epoch 17/20
# 219/219 [==============================] - 55s 252ms/step - loss: 0.0285 - last_time_step_mse: 0.0164 - val_loss: 0.0284 - val_last_time_step_mse: 0.0164
# Epoch 18/20
# 219/219 [==============================] - 55s 250ms/step - loss: 0.0280 - last_time_step_mse: 0.0158 - val_loss: 0.0275 - val_last_time_step_mse: 0.0154
# Epoch 19/20
# 219/219 [==============================] - 55s 251ms/step - loss: 0.0280 - last_time_step_mse: 0.0159 - val_loss: 0.0278 - val_last_time_step_mse: 0.0150
# Epoch 20/20
# 219/219 [==============================] - 55s 250ms/step - loss: 0.0276 - last_time_step_mse: 0.0154 - val_loss: 0.0276 - val_last_time_step_mse: 0.0156

# %% [markdown]
# # LSTMs

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.LSTM(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.LSTM(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=10,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 10s 27ms/step - loss: 0.0760 - last_time_step_mse: 0.0615 - val_loss: 0.0554 - val_last_time_step_mse: 0.0364
# Epoch 2/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0480 - last_time_step_mse: 0.0283 - val_loss: 0.0427 - val_last_time_step_mse: 0.0222
# Epoch 3/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0391 - last_time_step_mse: 0.0181 - val_loss: 0.0367 - val_last_time_step_mse: 0.0157
# Epoch 4/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0350 - last_time_step_mse: 0.0151 - val_loss: 0.0334 - val_last_time_step_mse: 0.0132
# Epoch 5/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0325 - last_time_step_mse: 0.0133 - val_loss: 0.0314 - val_last_time_step_mse: 0.0121
# Epoch 6/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0308 - last_time_step_mse: 0.0122 - val_loss: 0.0298 - val_last_time_step_mse: 0.0112
# Epoch 7/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0297 - last_time_step_mse: 0.0118 - val_loss: 0.0291 - val_last_time_step_mse: 0.0120
# Epoch 8/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0286 - last_time_step_mse: 0.0109 - val_loss: 0.0278 - val_last_time_step_mse: 0.0099
# Epoch 9/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0280 - last_time_step_mse: 0.0108 - val_loss: 0.0278 - val_last_time_step_mse: 0.0113
# Epoch 10/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0273 - last_time_step_mse: 0.0105 - val_loss: 0.0268 - val_last_time_step_mse: 0.0101
# Epoch 11/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0269 - last_time_step_mse: 0.0102 - val_loss: 0.0263 - val_last_time_step_mse: 0.0096
# Epoch 12/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0264 - last_time_step_mse: 0.0101 - val_loss: 0.0263 - val_last_time_step_mse: 0.0105
# Epoch 13/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0259 - last_time_step_mse: 0.0097 - val_loss: 0.0257 - val_last_time_step_mse: 0.0100
# Epoch 14/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0257 - last_time_step_mse: 0.0096 - val_loss: 0.0252 - val_last_time_step_mse: 0.0091
# Epoch 15/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0253 - last_time_step_mse: 0.0095 - val_loss: 0.0251 - val_last_time_step_mse: 0.0092
# Epoch 16/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0251 - last_time_step_mse: 0.0095 - val_loss: 0.0248 - val_last_time_step_mse: 0.0089
# Epoch 17/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0248 - last_time_step_mse: 0.0094 - val_loss: 0.0248 - val_last_time_step_mse: 0.0098
# Epoch 18/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0245 - last_time_step_mse: 0.0093 - val_loss: 0.0246 - val_last_time_step_mse: 0.0091
# Epoch 19/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0242 - last_time_step_mse: 0.0091 - val_loss: 0.0238 - val_last_time_step_mse: 0.0085
# Epoch 20/20
# 219/219 [==============================] - 5s 23ms/step - loss: 0.0239 - last_time_step_mse: 0.0089 - val_loss: 0.0238 - val_last_time_step_mse: 0.0086

# %%
model.evaluate(X_valid, Y_valid)
# Out:
# 63/63 [==============================] - 1s 9ms/step - loss: 0.0238 - last_time_step_mse: 0.0086
# [0.023788688704371452, 0.008560806512832642]

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, 50:, :]
Y_pred = model.predict(X_new)[:, -1][..., np.newaxis]

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %% [markdown]
# # GRUs

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.GRU(20, return_sequences=True, input_shape=[None, 1]),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=10,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 9s 26ms/step - loss: 0.0738 - last_time_step_mse: 0.0655 - val_loss: 0.0538 - val_last_time_step_mse: 0.0450
# Epoch 2/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0476 - last_time_step_mse: 0.0367 - val_loss: 0.0441 - val_last_time_step_mse: 0.0326
# Epoch 3/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0417 - last_time_step_mse: 0.0301 - val_loss: 0.0390 - val_last_time_step_mse: 0.0275
# Epoch 4/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0368 - last_time_step_mse: 0.0243 - val_loss: 0.0339 - val_last_time_step_mse: 0.0202
# Epoch 5/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0326 - last_time_step_mse: 0.0180 - val_loss: 0.0312 - val_last_time_step_mse: 0.0164
# Epoch 6/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0306 - last_time_step_mse: 0.0155 - val_loss: 0.0294 - val_last_time_step_mse: 0.0143
# Epoch 7/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0295 - last_time_step_mse: 0.0145 - val_loss: 0.0300 - val_last_time_step_mse: 0.0162
# Epoch 8/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0283 - last_time_step_mse: 0.0135 - val_loss: 0.0278 - val_last_time_step_mse: 0.0130
# Epoch 9/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0276 - last_time_step_mse: 0.0130 - val_loss: 0.0273 - val_last_time_step_mse: 0.0127
# Epoch 10/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0269 - last_time_step_mse: 0.0125 - val_loss: 0.0264 - val_last_time_step_mse: 0.0121
# Epoch 11/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0265 - last_time_step_mse: 0.0121 - val_loss: 0.0268 - val_last_time_step_mse: 0.0135
# Epoch 12/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0263 - last_time_step_mse: 0.0123 - val_loss: 0.0261 - val_last_time_step_mse: 0.0123
# Epoch 13/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0258 - last_time_step_mse: 0.0116 - val_loss: 0.0254 - val_last_time_step_mse: 0.0116
# Epoch 14/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0256 - last_time_step_mse: 0.0117 - val_loss: 0.0254 - val_last_time_step_mse: 0.0116
# Epoch 15/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0253 - last_time_step_mse: 0.0114 - val_loss: 0.0250 - val_last_time_step_mse: 0.0112
# Epoch 16/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0251 - last_time_step_mse: 0.0114 - val_loss: 0.0250 - val_last_time_step_mse: 0.0114
# Epoch 17/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0248 - last_time_step_mse: 0.0112 - val_loss: 0.0249 - val_last_time_step_mse: 0.0118
# Epoch 18/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0245 - last_time_step_mse: 0.0110 - val_loss: 0.0244 - val_last_time_step_mse: 0.0108
# Epoch 19/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0243 - last_time_step_mse: 0.0108 - val_loss: 0.0240 - val_last_time_step_mse: 0.0105
# Epoch 20/20
# 219/219 [==============================] - 5s 22ms/step - loss: 0.0240 - last_time_step_mse: 0.0106 - val_loss: 0.0238 - val_last_time_step_mse: 0.0103

# %%
model.evaluate(X_valid, Y_valid)
# Out:
# 63/63 [==============================] - 1s 9ms/step - loss: 0.0238 - last_time_step_mse: 0.0103
# [0.023785501718521118, 0.010262805968523026]

# %%
plot_learning_curves(history.history["loss"], history.history["val_loss"])
plt.show()

# %%
np.random.seed(43)

series = generate_time_series(1, 50 + 10)
X_new, Y_new = series[:, :50, :], series[:, 50:, :]
Y_pred = model.predict(X_new)[:, -1][..., np.newaxis]
# Out:
# WARNING:tensorflow:5 out of the last 508 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fee0a705a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.

# %%
plot_multiple_forecasts(X_new, Y_new, Y_pred)
plt.show()

# %% [markdown]
# ## Using One-Dimensional Convolutional Layers to Process Sequences

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential([
    keras.layers.Conv1D(filters=20, kernel_size=4, strides=2, padding="valid",
                        input_shape=[None, 1]),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.GRU(20, return_sequences=True),
    keras.layers.TimeDistributed(keras.layers.Dense(10))
])

model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train[:, 3::2], epochs=10,
                    validation_data=(X_valid, Y_valid[:, 3::2]))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 13s 18ms/step - loss: 0.0681 - last_time_step_mse: 0.0601 - val_loss: 0.0477 - val_last_time_step_mse: 0.0396
# Epoch 2/20
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0414 - last_time_step_mse: 0.0340 - val_loss: 0.0367 - val_last_time_step_mse: 0.0285
# Epoch 3/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0338 - last_time_step_mse: 0.0257 - val_loss: 0.0307 - val_last_time_step_mse: 0.0218
# Epoch 4/20
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0282 - last_time_step_mse: 0.0184 - val_loss: 0.0259 - val_last_time_step_mse: 0.0152
# Epoch 5/20
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0249 - last_time_step_mse: 0.0143 - val_loss: 0.0246 - val_last_time_step_mse: 0.0141
# Epoch 6/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0234 - last_time_step_mse: 0.0125 - val_loss: 0.0227 - val_last_time_step_mse: 0.0115
# Epoch 7/20
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0226 - last_time_step_mse: 0.0117 - val_loss: 0.0225 - val_last_time_step_mse: 0.0116
# Epoch 8/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0220 - last_time_step_mse: 0.0111 - val_loss: 0.0216 - val_last_time_step_mse: 0.0105
# Epoch 9/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0216 - last_time_step_mse: 0.0108 - val_loss: 0.0217 - val_last_time_step_mse: 0.0109
# Epoch 10/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0213 - last_time_step_mse: 0.0106 - val_loss: 0.0210 - val_last_time_step_mse: 0.0102
# Epoch 11/20
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0210 - last_time_step_mse: 0.0102 - val_loss: 0.0208 - val_last_time_step_mse: 0.0100
# Epoch 12/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0208 - last_time_step_mse: 0.0102 - val_loss: 0.0208 - val_last_time_step_mse: 0.0102
# Epoch 13/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0205 - last_time_step_mse: 0.0098 - val_loss: 0.0206 - val_last_time_step_mse: 0.0101
# Epoch 14/20
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0204 - last_time_step_mse: 0.0099 - val_loss: 0.0204 - val_last_time_step_mse: 0.0099
# Epoch 15/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0202 - last_time_step_mse: 0.0097 - val_loss: 0.0199 - val_last_time_step_mse: 0.0093
# Epoch 16/20
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0200 - last_time_step_mse: 0.0097 - val_loss: 0.0201 - val_last_time_step_mse: 0.0095
# Epoch 17/20
# 219/219 [==============================] - 3s 15ms/step - loss: 0.0196 - last_time_step_mse: 0.0093 - val_loss: 0.0197 - val_last_time_step_mse: 0.0091
# Epoch 18/20
# 219/219 [==============================] - 4s 16ms/step - loss: 0.0194 - last_time_step_mse: 0.0090 - val_loss: 0.0192 - val_last_time_step_mse: 0.0086
# Epoch 19/20
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0190 - last_time_step_mse: 0.0087 - val_loss: 0.0188 - val_last_time_step_mse: 0.0084
# Epoch 20/20
# 219/219 [==============================] - 3s 16ms/step - loss: 0.0186 - last_time_step_mse: 0.0083 - val_loss: 0.0184 - val_last_time_step_mse: 0.0080

# %% [markdown]
# # WaveNet

# %%
np.random.seed(42)
tf.random.set_seed(42)

model = keras.models.Sequential()
model.add(keras.layers.InputLayer(input_shape=[None, 1]))
for rate in (1, 2, 4, 8) * 2:
    model.add(keras.layers.Conv1D(filters=20, kernel_size=2, padding="causal",
                                  activation="relu", dilation_rate=rate))
model.add(keras.layers.Conv1D(filters=10, kernel_size=1))
model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=10,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/20
# 219/219 [==============================] - 4s 12ms/step - loss: 0.0668 - last_time_step_mse: 0.0543 - val_loss: 0.0366 - val_last_time_step_mse: 0.0230
# Epoch 2/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0326 - last_time_step_mse: 0.0194 - val_loss: 0.0298 - val_last_time_step_mse: 0.0169
# Epoch 3/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0284 - last_time_step_mse: 0.0157 - val_loss: 0.0272 - val_last_time_step_mse: 0.0150
# Epoch 4/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0262 - last_time_step_mse: 0.0138 - val_loss: 0.0255 - val_last_time_step_mse: 0.0132
# Epoch 5/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0247 - last_time_step_mse: 0.0124 - val_loss: 0.0244 - val_last_time_step_mse: 0.0121
# Epoch 6/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0240 - last_time_step_mse: 0.0118 - val_loss: 0.0232 - val_last_time_step_mse: 0.0108
# Epoch 7/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0233 - last_time_step_mse: 0.0112 - val_loss: 0.0229 - val_last_time_step_mse: 0.0109
# Epoch 8/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0226 - last_time_step_mse: 0.0106 - val_loss: 0.0227 - val_last_time_step_mse: 0.0106
# Epoch 9/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0220 - last_time_step_mse: 0.0101 - val_loss: 0.0221 - val_last_time_step_mse: 0.0105
# Epoch 10/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0217 - last_time_step_mse: 0.0099 - val_loss: 0.0210 - val_last_time_step_mse: 0.0091
# Epoch 11/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0211 - last_time_step_mse: 0.0092 - val_loss: 0.0206 - val_last_time_step_mse: 0.0089
# Epoch 12/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0207 - last_time_step_mse: 0.0087 - val_loss: 0.0210 - val_last_time_step_mse: 0.0096
# Epoch 13/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0203 - last_time_step_mse: 0.0085 - val_loss: 0.0198 - val_last_time_step_mse: 0.0079
# Epoch 14/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0200 - last_time_step_mse: 0.0081 - val_loss: 0.0197 - val_last_time_step_mse: 0.0079
# Epoch 15/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0197 - last_time_step_mse: 0.0078 - val_loss: 0.0193 - val_last_time_step_mse: 0.0075
# Epoch 16/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0196 - last_time_step_mse: 0.0078 - val_loss: 0.0192 - val_last_time_step_mse: 0.0074
# Epoch 17/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0191 - last_time_step_mse: 0.0073 - val_loss: 0.0189 - val_last_time_step_mse: 0.0072
# Epoch 18/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0188 - last_time_step_mse: 0.0070 - val_loss: 0.0187 - val_last_time_step_mse: 0.0071
# Epoch 19/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0187 - last_time_step_mse: 0.0070 - val_loss: 0.0184 - val_last_time_step_mse: 0.0068
# Epoch 20/20
# 219/219 [==============================] - 2s 10ms/step - loss: 0.0185 - last_time_step_mse: 0.0068 - val_loss: 0.0181 - val_last_time_step_mse: 0.0065

# %%
class GatedActivationUnit(keras.layers.Layer):
    def __init__(self, activation="tanh", **kwargs):
        super().__init__(**kwargs)
        self.activation = keras.activations.get(activation)
    def call(self, inputs):
        n_filters = inputs.shape[-1] // 2
        linear_output = self.activation(inputs[..., :n_filters])
        gate = keras.activations.sigmoid(inputs[..., n_filters:])
        return self.activation(linear_output) * gate

# %%
def wavenet_residual_block(inputs, n_filters, dilation_rate):
    z = keras.layers.Conv1D(2 * n_filters, kernel_size=2, padding="causal",
                            dilation_rate=dilation_rate)(inputs)
    z = GatedActivationUnit()(z)
    z = keras.layers.Conv1D(n_filters, kernel_size=1)(z)
    return keras.layers.Add()([z, inputs]), z

# %%
keras.backend.clear_session()
np.random.seed(42)
tf.random.set_seed(42)

n_layers_per_block = 3 # 10 in the paper
n_blocks = 1 # 3 in the paper
n_filters = 32 # 128 in the paper
n_outputs = 10 # 256 in the paper

inputs = keras.layers.Input(shape=[None, 1])
z = keras.layers.Conv1D(n_filters, kernel_size=2, padding="causal")(inputs)
skip_to_last = []
for dilation_rate in [2**i for i in range(n_layers_per_block)] * n_blocks:
    z, skip = wavenet_residual_block(z, n_filters, dilation_rate)
    skip_to_last.append(skip)
z = keras.activations.relu(keras.layers.Add()(skip_to_last))
z = keras.layers.Conv1D(n_filters, kernel_size=1, activation="relu")(z)
Y_proba = keras.layers.Conv1D(n_outputs, kernel_size=1, activation="softmax")(z)

model = keras.models.Model(inputs=[inputs], outputs=[Y_proba])

# %%
model.compile(loss="mse", optimizer="adam", metrics=[last_time_step_mse])
history = model.fit(X_train, Y_train, epochs=2,
                    validation_data=(X_valid, Y_valid))
# Out:
# Epoch 1/2
# 219/219 [==============================] - 5s 13ms/step - loss: 0.1300 - last_time_step_mse: 0.1260 - val_loss: 0.1229 - val_last_time_step_mse: 0.1199
# Epoch 2/2
# 219/219 [==============================] - 2s 10ms/step - loss: 0.1222 - last_time_step_mse: 0.1178 - val_loss: 0.1217 - val_last_time_step_mse: 0.1189
